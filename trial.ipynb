# %%
from cvr_analysis import CvrBusiness

# %%
mm = CvrBusiness()

# %%
data = mm.merge_tables()

# %%
dd = mm.analyze_companies(data, analysis_choices='low_debt')

# %%
list(dd)[0]
# Out:
# '33396007'

# %%
dd_1 = mm.analyze_companies(data, analysis_choices='declining')

# %%
list(dd_1)
# Out:
# ['10953103',
#  '77485112',
#  '15156082',
#  '29187932',
#  '73449413',
#  '11426484',
#  '20475145',
#  '26059925',
#  '13664048',
#  '34208433',
#  '76398518',
#  '35381236',
#  '30509935',
#  '37277827',
#  '20325488',
#  '13837074',
#  '28899785',
#  '39194279',
#  '32282598',
#  '30536134',
#  '35835008',
#  '26937868',
#  '38158287',
#  '24232891',
#  '36955457',
#  '16876194',
#  '27716946',
#  '34895872',
#  '35054847',
#  '38506404',
#  '25790944',
#  '36707364',
#  '36559241',
#  '34712816',
#  '20838876',
#  '40091033',
#  '40366180',
#  '31858267',
#  '38290355',
#  '32948987',
#  '10040159',
#  '27716873',
#  '12337248',
#  '19208648',
#  '30352106',
#  '38704230',
#  '34895112',
#  '38213288',
#  '11447899',
#  '37073199',
#  '40003088',
#  '30580532',
#  '39653028',
#  '26091268',
#  '12701179',
#  '33830513',
#  '14762140',
#  '89357411',
#  '31780446',
#  '35669353',
#  '33961316',
#  '25859448',
#  '34576319',
#  '11475604',
#  '41563818',
#  '27317510',
# ...

# %%
trying = mm.apply_filter(dd_1, data)
