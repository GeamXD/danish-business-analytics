# %%
import plotly.express as px
import pandas as pd
# %load_ext sql

# %%
# connect to sqlite database
# %sql sqlite:///dataset/cvr_database.db

# %%
# Outputs tables in cvr_database.db
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [('observations',), ('financials',), ('company',)]

# %%
# Query the database to get the columns in each table
observations_cols = %sql PRAGMA table_info('observations')
financials_cols = %sql PRAGMA table_info('financials')
company_cols = %sql PRAGMA table_info('company')
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
#  * sqlite:///dataset/cvr_database.db
# Done.
#  * sqlite:///dataset/cvr_database.db
# Done.

# %%
observations_cols
# Out:
# [(0, 'title', 'TEXT', 0, None, 0),
#  (1, 'priority', 'INTEGER', 0, None, 0),
#  (2, 'status', 'TEXT', 0, None, 0),
#  (3, 'description', 'TEXT', 0, None, 0),
#  (4, 'cvr', 'TEXT', 0, None, 0)]

# %%
financials_cols
# Out:
# [(0, 'publication_date', 'TEXT', 0, None, 0),
#  (1, 'property_and_buildings', 'REAL', 0, None, 0),
#  (2, 'gross_profit_loss', 'REAL', 0, None, 0),
#  (3, 'return_on_investment', 'REAL', 0, None, 0),
#  (4, 'intangible_assets', 'REAL', 0, None, 0),
#  (5, 'finance_income', 'REAL', 0, None, 0),
#  (6, 'employee_expense', 'REAL', 0, None, 0),
#  (7, 'pdf_url', 'TEXT', 0, None, 0),
#  (8, 'provisions', 'REAL', 0, None, 0),
#  (9, 'current_ratio', 'REAL', 0, None, 0),
#  (10, 'fixtures_and_equipment', 'REAL', 0, None, 0),
#  (11, 'proposed_dividend_recognised_in_equity', 'REAL', 0, None, 0),
#  (12, 'solvency_ratio', 'REAL', 0, None, 0),
#  (13, 'total_gross_profit', 'REAL', 0, None, 0),
#  (14, 'current_assets', 'REAL', 0, None, 0),
#  (15, 'depreciation', 'REAL', 0, None, 0),
#  (16, 'reporting_period_start_date', 'TEXT', 0, None, 0),
#  (17, 'profit_loss_from_ordinary_operating_activities', 'REAL', 0, None, 0),
#  (18, 'property_plant_and_equipment', 'REAL', 0, None, 0),
# ...

# %%
company_cols
# Out:
# [(0, 'industry_text', 'TEXT', 0, None, 0),
#  (1, 'company_form_code', 'INTEGER', 0, None, 0),
#  (2, 'employee_count', 'REAL', 0, None, 0),
#  (3, 'long_description', 'TEXT', 0, None, 0),
#  (4, 'status', 'TEXT', 0, None, 0),
#  (5, 'industry_code', 'INTEGER', 0, None, 0),
#  (6, 'name', 'TEXT', 0, None, 0),
#  (7, 'cvr_number', 'INTEGER', 0, None, 0),
#  (8, 'short_description', 'TEXT', 0, None, 0),
#  (9, 'industry_sector', 'TEXT', 0, None, 0),
#  (10, 'unit_type', 'TEXT', 0, None, 0),
#  (11, 'website_url', 'TEXT', 0, None, 0),
#  (12, 'last_updated', 'TEXT', 0, None, 0),
#  (13, 'last_loaded', 'TEXT', 0, None, 0),
#  (14, 'responsible_data_providers', 'TEXT', 0, None, 0),
#  (15, 'sort_key', 'TEXT', 0, None, 0),
#  (16, 'p_number', 'INTEGER', 0, None, 0),
#  (17, 'unit_number', 'INTEGER', 0, None, 0),
#  (18, 'effective_actor', 'TEXT', 0, None, 0),
#  (19, 'alt_names', 'TEXT', 0, None, 0),
#  (20, 'ad_protected', 'INTEGER', 0, None, 0),
# ...

# %%
# %sql SELECT COUNT(DISTINCT(title)) FROM observations LIMIT 15;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [(13,)]

# %%
# Count distinct priority in observations
# %sql SELECT COUNT(DISTINCT(priority)) FROM observations LIMIT 15;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [(11,)]

# %%
# Print out the first 5 rows of the observations table
# %sql SELECT * FROM observations LIMIT 5;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [('obs.companyPositiveEquity', 2, 'Positive', 'obs.companyPositiveEquityPositiveDesc', '63053112'),
#  ('obs.companyYearlyResultTitle', 3, 'Positive', 'obs.companyYearlyResultPositiveDesc', '63053112'),
#  ('obs.companyAnnouncementDeltaTitle', 5, 'Positive', 'obs.companyAnnouncementDeltaPositive', '63053112'),
#  ('obs.accountRevisedTitle', 6, 'Positive', 'obs.accountRevisedPositiveDesc', '63053112'),
#  ('obs.companyAgeTitle', 7, 'Positive', 'obs.companyAgePositiveDesc', '63053112')]

# %%
# distinct values in the status column
# %sql SELECT DISTINCT(status) FROM observations LIMIT 15;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [('Positive',), ('Neutral',), ('Negative',)]

# %%
# COUNT ALL RECORDS IN observations
# %sql SELECT COUNT(*) FROM observations;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [(676605,)]

# %%
# Distinct values in cvr_number column
# %sql SELECT COUNT(DISTINCT(cvr)) FROM observations;
# Out:
#  * sqlite:///dataset/cvr_database.db
# Done.
# [(66735,)]

# %%
# con = sqlite3.connect('dataset/cvr_database.db')
# cur = con.cursor()
# cur.execute("PRAGMA table_fetchallinfo('company');")
# lt = cur.fetchmany(10)
# cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
# cur.fetchmany(1)
# lt.DataFrame()
